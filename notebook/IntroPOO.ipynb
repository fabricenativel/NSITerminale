# %% [markdown]
# # <font color=darkred> &#10070; Introduction à la programmation orienté objet </font>
#
# ![des.jpg](attachment:des.jpg)
# L'image ci-dessus présente quelques dés à jouer, comme vous pouvez le constaster, il en existe de différentes sortes en plus du traditionnel dé à six faces bien connu (le dé orange sur l'image) on voit ici des dés à 4, 8, 10, 12 et 20 faces.
#
# De nombreux jeux de dés existent certains connus comme par exemple le [421](https://fr.wikipedia.org/wiki/421_(jeu)) et notre hypothèse de départ est que nous voulons créer un jeu à base de dés.
#
# ## <font color=darkblue> &diams; Paradigme procédural </font>
#
# De façon classique, notre programme va probablement contenir une fonction qui simule le lancer d'un dé.

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
# 1. <font color='green'> Ecrire une fonction <code>lancer_des(nombre_faces)</code> qui renvoie le résultat aléatoire d'un lancer de dés ayant le nombre de faces indiqué. Par exemple, <code>lancer_des(12)</code> renvoie un entier au hasard entre 1 et 12. <br>
#     &#9755; Penser à utiliser la foncion <code>randint</code> du module <code>random</code>
# </font>

# %%
# Importation de la fonction randint du module random

# Ecrire votre fonction ici


# un test pour votre fonction

# %% [markdown]
# Cette fonction sera probablement appelé à de nombreuses reprises à l'intérieur de notre programme.
#
# Une façon de concevoir, modéliser et programmer une solution à un problème s'appelle un **paradigme de programmation** et celui que nous utilisons ici est le **paradigme procédural** c'est à dire l'écriture de fonction appellées ensuite à de multiples endroits du programme.

# %% [markdown]
# ## <font color=darkblue> &diams; Penser objet ! </font>
#
# Une autre façon de **penser** notre programme est de considérer que nous allons manipuler des objets qui possèdent certaines caractéristiques et sur lesquels nous pouvons agir.
#
# Dans notre exemple, le dé est vu comme un objet qui possède un nombre de faces et une couleur, c'est ce que nous appellerons les <font color="navy"><b>attributs</b></font> de l'objet et que nous pouvons lancer c'est ce que nous appellerons une <font color="navy"><b>méthode</b></font> de l'objet.
#
# Nous devons faire la différence entre le modèle d'un dé défini ci-dessus par ses attributs et méthode, c'est que nous appelerons une <font color="navy"><b>classe</b></font> et un dé en particulier que nous appelerons <font color="navy"><b>objet</b></font>.
#
# Dans tout langage de programmation, et donc en Python, on doit disposer d'une méthode particulière permettant de créer un objet à partir de sa classe. Donnons un exemple précis, si nous indiquons qu'un dé a un nombre de faces et une couleur (nous définissions un modèle, c'est à dire une classe). Et, il faut allors  pouvoir  dire qu'on veut créer un dé en particulier à partir de ce modèle par exemple un dé orange à six faces. Créer un objet à partir de sa classe s'appelle <font color="navy"><b>instancier</b></font> la classe, on dit donc qu'un objet est l'instanciation d'une classe. Cette méthode spéciale s'appelle le <font color="navy"><b>constructeur</b></font>.
#
# Avant de passer à l'écriture en Python et donc de découvrir la syntaxe objet de Python, résumons par un schéma notre réflexion :

# %% [markdown]
# ![POO.png](attachment:POO.png)

# %% [markdown]
# Dans l'exemple des dés :
# 1. les objets réels sont les dés
# 2. dans la modélisation, les attributs d'un dé sont sa couleur et son nombre de faces
# 3. en instancier la classe dé, on obtiendra un "dé informatique" qui représente notre dé réel.

# %% [markdown]
# ## <font color=darkblue> &diams; La syntaxe de  Python </font>
#
# * En python, la définition d'une classe commence par le mot clé `class` suivi du nom de la classe (qui par convention commence par une majuscule) et enfin du caractère `:`
# * Les méthodes de la classe sont en quelque sorte des fonctions définies pour la classe et qui s'appliqueront aux objets. Par conséquent la définition d'une méthode est similaire à celle d'une fonction c'est à dire qu'on retrouve le mot clé `def`. Pour nommer l'objet auquel la méthode s'applique on utilisera le mot clé `self`
# * Les méthodes spéciales en Python ont leur nom encadrés par des double underscore `__` et le constructeur en Python est `init`
# Avec ces explications, vous devriez comprendre le code commenté ci-dessous :

# %%
import random

# Définition d'une classe : class <nom_de_la_classe>:
class De:
    
    # Le constructeur permettant de créer des objets de cette classe
    def __init__(self,nb_faces,couleur):
        self.nombre_faces=nb_faces
        self.couleur=couleur
    
    # La méthode de lancer du dé 
    def lancer(self):
        return random.randint(1,self.nombre_faces)

# %% [markdown]
# Comme indiqué plus haut, il nous faut à présent **instancier** cette classe pour créer un objet informatique représentant un dé en particulier.

# %%
un_de = De(10,"rouge")

# %% [markdown]
# Nous venons de créer *un dé* en particulier, il a 10 faces et il est rouge !
#
# Ce dé dispose immédiatement des méthodes de classe dont il est issu, on peut donc le lancer :

# %%
un_de.lancer()

# %% [markdown]
# Arrêtons nous un instant sur la syntaxe précédente, permettant d'utiliser une méthode sur un objet, elle est de la forme : `<objet>.<methode>`
# Nous avons déjà utilisé à de multiples reprises cette syntaxe en Python, à titre d'exemples

# %%
L=["premier","second"]
L.append("troisième")
L

# %% [markdown]
# En effet, Python est un langage orienté objet et les listes que nous manipulons depuis longtemps sont des objets possédant une méthode `append` permettant d'ajouter une élément en fin de liste.

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
# <font color=green>On veut créer une classe `Qcm` qu'on modélisé par un enoncé de la question, trois mauvaises réponses et une bonne réponse.<br>
# 2. Compléter la définition de classe ci-dessous<br>
# 3. Ajouter une méthode `voir` qui affiche à l'écran l'énoncé et les 4 propositions de réponses</font>

# %%
# Une classe modélisant un qcm
_____ Qcm:
    
    # Constructeur de la classe
    def ________(self,enonce,mauvaise1,mauvaise2,mauvaise3,bonne):
        self._____ = _______
        self._____ = _______
        self._____ = _______
        self._____ = _______
        self._____ = _______
    
    # La méthode voir pour afficher la question à choix multiples

# %% [markdown]
# <font color=green>
#
# 2. Instancier la classe `Qcm` sur la question de votre choix
# 3. Utiliser la méthode `voir` sur l'objet crée à la méthode précédente afin d'afficher votre question</font>

# %%
# Vos réponses ici

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
# <font color=green> On modélise un animal domestique par les attributs suivants son nom, son type et son propriétaire.
#
# 4. Ecrire en Python la classe `Animal_domestique` ainsi que son constructeur
# 5. Instancier cette classe de façon à "créer" :
#     * Tom, le poisson rouge de Pierre
#     * Gropif, le chien de Rémi
#     * Noisette, le hamster de Patricia</font>

# %%
# Vos réponse ici

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
# <font color=green>
#
# 6. Ecrire en Python la classe `Rectangle` qui possède les attributs longueur et largeur
# 7. Ecrire pour cette classe les méthodes suivantes :
#     * `perimetre` qui renvoie le périmètre du rectangle
#     * `aire` qui renvoie l'aire du rectangle
#     * `est_carre` qui renvoie `True` si le rectangle est un carré et `False` sinon</font>

# %%
# Vos réponse ici

# %% [markdown]
# ## <font color=green> &#9998; Exercices :  </font>
# <font color=green>
#
# 8. Le module Turtle de Python utilise la programmation objet. Donner 3 attributs de l'objet <code>turtle</code>.
# 9. Donner 3 méthodes d'un objet de type <code>turtle</code>
# </font>

# %%
# Vos réponse ici
